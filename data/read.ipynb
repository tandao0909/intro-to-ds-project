# %%
import pandas as pd
df = pd.read_csv('housing.csv',sep='\t')
df
# Out:
#                                                   Title  Price  \
# 0     Bán nhà đẹp 4 tầng Bùi Tá Hán, An Phú, Q2 4x20...    6.5
# 1     (VH25) BÁN NHÀ 3 TẦNG MẶT TIỀN ĐƯỜNG 19/5 KHU ...   15.8
# 2     (VH25) BÁN NHÀ 3 TẦNG MẶT TIỀN ĐƯỜNG 19/5 KHU ...    9.2
# 3     HXH-NGUYỄN HỮU TIẾN, TÂN PHÚ-57M2 ngang 4.1m- ...    9.2
# 4     Bán nhà kế Phạm Văn Hai Phường 6 Tân Bình, 55m...    6.1
# ...                                                 ...    ...
# 3353  BÁN NHÀ MẶT TIỀN ĐƯỜNG SỐ+LÊ THỊ HOA.PHƯỜNG BÌ...    5.9
# 3354  Bán Nhà Đặng Văn Bi, Thủ Đức, Nhà Đẹp Giá Rẻ, ...    6.7
# 3355  Nhà đẹp Ngọc Lâm, 70m x 6tầng, gara 2 ôtô, tha...    5.2
# 3356  BÁN NHÀ C4 60m2.GIÁ BAO ĐẦU TƯ-GẦN NGÃ TƯ BÌNH...   12.8
# 3357  CẦN BÁN NHÀ C4.60m2. Ngay ngã tư bình phước.HB...    3.4
#
#       Diện tích (m2)  Số phòng ngủ  Số phòng WC  \
# 0               80.0           4.0          4.0
# 1              138.0           5.0          6.0
# 2              138.0           5.0          6.0
# ...
