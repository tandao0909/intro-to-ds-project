# %%
import pandas as pd
from Pipeline_Housing import num_pipeline, SplitData

housing = pd.read_csv('last_hope.csv', sep='\t')

housing_prepared, train_set_scaled, test_set_scaled = num_pipeline.fit_transform(housing)

# %%
housing_prepared.to_csv('housing_prepared.csv', sep='\t', index=False)
housing_prepared
# Out:
#             ID  Log price (1 billion VND)  Log area (square meters)  \
# 0    -1.731760                   0.827100                  0.505354
# 1    -1.731178                  -0.327715                 -1.283832
# 2    -1.730597                  -0.386089                 -1.038063
# 3    -1.730015                   0.574668                  2.927265
# 5    -1.729433                   1.163712                  1.769335
# ...        ...                        ...                       ...
# 6294  1.729433                  -0.327715                 -0.086254
# 6295  1.730015                   1.012426                 -0.236331
# 6296  1.730597                   0.662988                  1.186748
# 6297  1.731178                   0.138697                 -0.398426
# 6298  1.731760                  -0.810359                 -0.981014
#
#       (Log) Bedrooms  (Log) WC   Parking  For rent  Infrastructure    Facade  \
# ...

# %%
train_set_scaled.to_csv('train_set_scaled.csv', sep='\t', index=False)
train_set_scaled
# Out:
#             ID  Log price (1 billion VND)  Log area (square meters)  \
# 6235  1.698602                  -0.405996                 -0.574633
# 5741  1.424615                   1.563954                  0.184162
# 1602 -0.844066                   0.167636                  0.053464
# 970  -1.197166                  -0.736022                 -0.236331
# 1723 -0.776587                  -0.146298                 -0.529123
# ...        ...                        ...                       ...
# 1053 -1.151792                  -1.953957                 -0.086254
# 295  -1.570625                  -0.530523                  0.086938
# 126  -1.665445                   0.017814                  0.152270
# 33   -1.713727                  -1.054814                 -0.767647
# 1774 -0.748665                  -1.858273                 -0.398426
#
#       (Log) Bedrooms  (Log) WC   Parking  For rent  Infrastructure    Facade  \
# ...

# %%
test_set_scaled.to_csv('test_set_scaled.csv', sep='\t', index=False)
test_set_scaled
# Out:
#             ID  Log price (1 billion VND)  Log area (square meters)  \
# 3864  0.396728                  -2.055273                  0.422685
# 5567  1.327469                   0.865795                  0.053464
# 1308 -1.009272                  -1.559921                  1.087942
# 5556  1.321652                   0.167636                  2.638098
# 4518  0.759136                   1.029907                  0.896953
# ...        ...                        ...                       ...
# 6209  1.684059                   1.211325                 -0.767647
# 5334  1.203564                   0.383151                  0.053464
# 2148 -0.542157                  -1.640023                  1.005273
# 751  -1.318744                   1.909484                  1.769335
# 2141 -0.545647                  -1.144671                 -1.219537
#
#       (Log) Bedrooms  (Log) WC   Parking  For rent  Infrastructure    Facade  \
# ...
