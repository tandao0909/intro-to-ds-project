# %%
import pandas as pd
df1 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page809.csv',sep='\t')
df2 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page819.csv',sep='\t')
df3 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page829.csv',sep='\t')
df4 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page839.csv',sep='\t')
df5 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page849.csv',sep='\t')

# %%
df = pd.concat([df1,df2,df3,df4,df4,df5],axis=0,ignore_index=True)

# %%
df.drop_duplicates(inplace=True)

# %%
import numpy as np
df.set_index(np.arange(len(df)),inplace=True)

# %%
df.isna().sum()
# Out:
# Title               0
# Price               0
# Links               0
# Diện tích (m2)     42
# Số phòng ngủ      336
# Số phòng WC       396
# Địa chỉ           399
# Description         0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                                  Title       Price  \
# 0    Chính chủ cần bán gấp nhà Đường 4, Long bình, ...  3600000 tỷ
# 1    BÁN NHÀ TẠI XÃ ĐÀN, ĐỐNG ĐA, 35M2, 4 TẦNG CHỈ ...      3.5 tỷ
# 2    Bán Nhà Ngõ Văn Chương - Đống Đa, 5 Tầng, Ngõ ...        4 tỷ
# 3    Hiếm Nhà Bán ! Nhà Láng Hạ, Đống Đa Lô Góc Val...      3.4 tỷ
# 4    Bán nhà mặt phố Lò Đúc, Hai Bà Trưng 52m, 6 tầ...     28.5 tỷ
# ..                                                 ...         ...
# 994  Nhà hẻm 4m, Trần Hữu Trang, 3.5 x 14m, 3PN, 6....      6.2 tỷ
# 995  Đẹp, kiên cố, Hoàng Ngọc Phách, 5.1 x 9m, 3 lầ...      5.5 tỷ
# 996  Nội thất đẹp, Lê Cảnh Tuân, 4 x 8.5m, 2 lầu, 4...     4.45 tỷ
# 997  Hẻm 3.5m, Phan Đình Phùng, 3.6 x 12m, 2 lầu, 5...      5.7 tỷ
# 998  Nhà hẻm 3.5m, Trần Hữu Trang, 1T2L, 4 x14m, ch...      6.3 tỷ
#
#                                                  Links  Diện tích (m2)  \
# 0    https://batdongsan.vn/chinh-chu-can-ban-gap-nh...            61.0
# ...

# %%
df.to_csv('next_1000(1)_19062024.csv',sep='\t',index=False)
