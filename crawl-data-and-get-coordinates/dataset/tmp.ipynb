# %%
import pandas as pd
df1 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page569.csv',sep='\t')
df2 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page589.csv',sep='\t')
df3 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page609.csv',sep='\t')
df4 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page629.csv',sep='\t')
df5 = pd.read_csv('/home/tiamo/Documents/code/Intro to DS 2024/Project1/intro-to-ds-project/crawl-data-and-get-coordinates/dataset/page649.csv',sep='\t')

# %%
df = pd.concat([df1,df2,df3,df4,df4],axis=0)
len(df)
# Out:
# 1993

# %%
import numpy as np
df.set_index(np.arange(len(df)))
# Out:
#                                                   Title       Price  \
# 0     BÁN NHÀ DT ĐẤT 5X16M, TRỆT 2 LẦU, FULL NỘI THẤ...      6.5 tỷ
# 1                BÁN NHÀ 2 MT ĐƯỜNG 52M KHU LOVERA PARK       10 tỷ
# 2     Nhà hiếm cực kỳ đẹp 57m2, HXH, Linh Tây Thủ Đứ...  5300000 tỷ
# 3     Bán Nhà VP Tôn Đức Thắng Đống Đa 77m2 8T Thang...       33 tỷ
# 4           Phạm Văn Đồng 3.1 tỷ 2 tầng 4x11 P 1 Gò Vấp      3.1 tỷ
# ...                                                 ...         ...
# 1988  Giảng Viên Đại Học bán nhà Nguyễn Trãi, SÁT PH...      4.3 tỷ
# 1989  Nhà mới 5 tầng BTCT đường Thích Quảng Đức Trun...      4.9 tỷ
# 1990  Bán nhà HXH 8M thông đường LÊ VĂN QUỚI, DT: 4x...      7.5 tỷ
# 1991  Bán nhà HXH 8M thông đường LÊ VĂN QUỚI, DT: 4x...      7.5 tỷ
# 1992  Bán nhà HXH thông đường TÂN HOÀ ĐÔNG, DT: 4x16...     4.85 tỷ
#
#                                                   Links  Diện tích (m2)  \
# 0     https://batdongsan.vn/ban-nha-dt-dat-5x16m-tre...            80.0
# ...

# %%
df.isna().sum()
# Out:
# Title               0
# Price               0
# Links               0
# Diện tích (m2)    154
# Số phòng ngủ      730
# Số phòng WC       822
# Địa chỉ           917
# Description         0
# dtype: int64

# %%
df.to_csv('next_2000.csv',sep='\t',index=False)
