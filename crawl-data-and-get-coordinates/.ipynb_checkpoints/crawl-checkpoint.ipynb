# %%
import os
import re
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np

# %%
os.environ['PATH'] += r"/usr/local/bin/"
driver = webdriver.Firefox()
driver.maximize_window()

# %%
def get_data(text):
    reg_template = {"Area":'Diện tích:\s*(\d+)',
                "Room":'Phòng ngủ:\s*(\d+)',
                "WC":'Phòng WC:\s*(\d+)',
                "Location":'Địa chỉ:\s*(.+)'}
    list_params = []
    for i,name in enumerate(reg_template):
        x = re.search(r'{}'.format(reg_template[name]),text)
        if x:
            list_params.append(x.group(1))
        else:
            list_params.append(np.nan)
    return list_params

# %%
base_url = "https://batdongsan.vn/ban-nha/"
report =    pd.DataFrame(columns=['Title', 'Price', 'Links',\
            'Diện tích (m2)', 'Số phòng ngủ','Số phòng WC', 'Địa chỉ'\
            ,'Description'])

page = 2

for i in range(page):
    url = base_url + "p{}".format(i+1)
    driver.get(url)
    driver.implicitly_wait(1)
    try:
        elements = driver.find_elements('css selector','.uk-width-medium-7-10 .name [href]')
        elements_price = driver.find_elements('css selector','.price')
    except:
        continue
    
    title = [element.text for element in elements]

    links = [element.get_attribute('href') for element in elements]

    price = [element.text for element in elements_price]
    
    df1 = pd.DataFrame(zip(title,price,links),columns=['Title','Price','Links'])
    
    data = []
    
    n = len(df1)

    for j in range(n):
        try:
            driver.get(links[j])
            params = driver.find_element('css selector',".param")
            content = driver.find_element('css selector',".content")
        except:
            df1.drop(j,axis=0,inplace=True)
            continue
        params_ = get_data(params.text)
        params_.append(content.text)
        data.append(params_)

    tmp = np.vstack([item for item in data])
    df2 = pd.DataFrame(tmp,columns=['Diện tích (m2)','Số phòng ngủ','Số phòng WC','Địa chỉ', 'Description'])
    df1 = pd.concat([df1,df2],axis=1)
    report = pd.concat([report,df1],axis=0)
    report.set_index(np.arange(len(report)),inplace=True)
    report.to_csv('report.csv',sep="\t",index=False)

report
# Out:
#                                                 Title  \
# 0   Chưa tới 30tr/m2 - Hàng ngộp bank BAO ĐẦU TƯ ...
# 1   Bán nhà HXH Âu Cơ Phường 9 Tân Bình, 51m2 3 Tầ...
# 2   SÁT MẶT TIỀN PHAN ĐĂNG LƯU, PHƯỜNG 7, PHÚ NHUẬ...
# 3   CHỦ GẤP BÁN TRƯỚC TẾT LÊ HỒNG PHONG QUẬN 5 RA ...
# 4   LŨY BÁN BÍCH,TÂN PHÚ-DIỆN TÍCH KHỦNG 96M2 ( 4....
# 5   Bán nhà trong ngõ Lê Trọng Tấn, TK hiện đại, 4...
# 6   Bán nhà trong ngõ Lê Trọng Tấn, TK hiện đại, 4...
# 7   BÁN NHÀ PHỐ HOÀNG VĂN THÁI 59M - MT 3.6M - NGÕ...
# 8   ✅ BÁN NHÀ MỚI ĐẸP 7 X 13, CHỈ 3.5 TỶ, HẺM XE H...
# 9   SIÊU PHẨM Chào bán căn Biệt Thự mặt đường Lê H...
# 10  Bán Nhà Mặt tiền đường Kha Vạn Cân, P. Linh Đô...
# 11  Bán nhà Âu Cơ-Tây Hồ 42m, NGÕ THÔNG, DÂN XÂY 4...
# 12  Bán nhà phố Đào Tấn, Ba Đình, gần phố, ở ngay ...
# 13                                    Trương Đức Toàn
# 14  Nhà 6 Tầng, Hộ Khẩu Cầu Giấy, Ô Tô Đỗ Cửa, Ngõ...
# 15  SÁT MẶT TIỀN BẠCH ĐẰNG, PHƯỜNG 14, BÌNH THẠNH,...
# 16  Phân lô ô tô tránh Hà Đông, dân trí cao, an ni...
# 17  Bán nhà 2 mặt tiền đường Phạm Văn Đồng, Thủ Đứ...
# 18  Cửa nhựa giá rẻ lắp đặt phòng ngủ và Toilet | ...
# 19  Chỉ 2 tỉ sở hữu shophouse 4 tầng, chân đế chun...
# 0   Bán nhà mới leng keng 110m2 đường ô tô (X.Tân ...
# 1   Bán nhà mới leng keng 110m2 đường ô tô (X.Tân ...
# 2   NHÀ MẶT TIỀN KHU SẦM UẤT QUẬN 4, 4 TẦNG, NGAY ...
# 3   Bán nhà ngõ Thổ quan, Khâm Thiên, gần ô tô, ở ...
# 4   BÁN NHÀ MẶT PHỐ THANH XU N, DT134M2X8T, MT5.4M...
# 5   BÁN NHÀ PHỐ TRƯỜNG CHINH 68M - TT THANH XU N M...
# 6   Nhà Chính chủ hẻm taxi Mễ Cốc, P15, Q8. Giá 3.4tỷ
# 7   Bán nhà Trần Xuân Soạn, phường Tân Hưng, Q.7 –...
# 8   Văn Quán Hà Đông, nhà đẹp ở luôn, ô tô đỗ cửa,...
# 9   GIẢM SÂU 1,7 TỶ- NHỈNH 8 TỶ -HXH 12M NGAY HÒA ...
# 10  11.4 Tỷ Diện Tích 90M2 Nhà 6 Tầng Mặt Tiền Mỹ ...
# 11  HẺM XE HƠI-NHÀ ĐẸP LUNG LINH NGAY EMART GÒ VẤP...
# 12  Bán nhà mặt tiền kinh doanh Bùi Tá Hán, An Phú...
# 13  Bán nhà đẹp 50m2 *2 Nguyễn Khuyến, Bình Thạnh ...
# 14  HOÀNG HOA THÁM 30m X5t X MT 5m 4,3 Tỷ - 5 TẦNG...
# 15  Bán Nhà mặt ngõ Bùi Xương Trạch,, Thanh Xuân, ...
# 16  Bán nhà HXH Bùi Thế Mỹ Phường 10 Tân Bình, 40m...
# 17  BÁN NHÀ BÌNH THẠNH 80M2 - 5PN 5WC - DÒNG TIỀN ...
# 18  The number 1 reputable Google Ads advertising ...
# 19  (PHA12) BÁN NHÀ 2 TẦNG HẺM 3M KHU ĐÔ THỊ VCN ...
#
#                                                 Price  \
# 0   Giá bán\nDưới 500 triệu\nTừ 500 - 800 triệu\nT...
# 1                                       3899000000 tỷ
# 2                                              5.5 tỷ
# 3                                              4.6 tỷ
# 4                                             7.35 tỷ
# 5                                          Thỏa thuận
# 6                                             3.95 tỷ
# 7                                             3.95 tỷ
# 8                                             7.95 tỷ
# 9                                          Thỏa thuận
# 10                                              17 tỷ
# 11                                              19 tỷ
# 12                                            5.29 tỷ
# 13                                             8.6 tỷ
# 14                                            21.8 tỷ
# 15                                            5.95 tỷ
# 16                                               4 tỷ
# 17                                             6.9 tỷ
# 18                                              19 tỷ
# 19                                         Thỏa thuận
# 14  https://batdongsan.vn/hoang-hoa-tham-30m-x5t-x...             30
# 15  https://batdongsan.vn/ban-nha-mat-ngo-bui-xuon...             43
# 16  https://batdongsan.vn/ban-nha-hxh-bui-the-my-p...            nan
# 17  https://batdongsan.vn/ban-nha-binh-thanh-80m2-...             80
# 18  https://batdongsan.vn/the-number-1-reputable-g...            150
# 19  https://batdongsan.vn/pha12-ban-nha-2-tang-hem...             55
#
#    Số phòng ngủ Số phòng WC  \
# 0             2           1
# 1           nan         nan
# 2             2           2
# 3           nan         nan
# 4             2           1
# 5             4           3
# 6             4           3
# 7           nan         nan
# 8             3           3
# 9             6           6
# 10          nan         nan
# 11            4           3
# 12            4           5
# 13            8           8
# 14            3           4
# 15            3           3
# 16          nan         nan
# 17          nan         nan
# 18          nan         nan
# 19          nan         nan
# 0             3           2
# 1             3           2
# 2             5           6
# 3             3           3
# 4             8          88
# 5           nan         nan
# 6           nan         nan
# 7           nan         nan
# 8           nan           3
# 9             7           3
# 10          nan         nan
# 11            4           4
# 12            6           6
# 13          nan         nan
# 14            3           4
# 15            1           1
# 16          nan         nan
# 17          nan           5
# 18           12          12
# 19            2           2
#
#                                               Địa chỉ  \
# 0                               Thành phố Hồ Chí Minh
# 1                             ÂU CƠ PHƯỜNG 9 TÂN BÌNH
# 2                                                 nan
# 3                       LÊ HỒNG PHONG PHƯỜNG 2 QUẬN 5
# 4                                                 nan
# 5                                     La Khê, Hà Đông
# 6                                     La Khê, Hà Đông
# 7                                                 nan
# 8                                                 nan
# 9                 Lê Hồng Phong, Ngô Quyền, Hải Phòng
# 10  Đường Kha Vạn Cân, Phường Linh Đông, Quận Thủ ...
# 11                                                nan
# 12                                                nan
# 13                              Thành phố Hồ Chí Minh
# 14                                                nan
# 15                                                nan
# 16                                   Bà Triệu Hà Đông
# 17  Đường Phạm Văn Đồng, Phường Hiệp Bình Chánh, Q...
# 18                                                nan
# 19                   Khu đô thị Vsip Từ Sơn, Bắc Ninh
# 0                                                 nan
# 1                                                 nan
# 2                                     Đường Xóm Chiếu
# 3                                                 nan
# 4                                                 nan
# 5                                                 nan
# 6             Nhà Chính chủ hẻm taxi Mễ Cốc, P15, Q8.
# 7                                                 nan
# 8                                    Văn Quán Hà Đông
# 9                                                 nan
# 10                                  Thành phố Đà Nẵng
# 11                                                nan
# 12                                Quận 2, Hồ Chí Minh
# 13          Nguyễn Khuyến, phường 12, quận Bình Thạnh
# 14                                                nan
# 15   HH02-2B kđt Thanh Hà- Kiến Hưng- Hà Đông- Hà Nội
# 16                                                nan
# 17                                   BÌNH THẠNH , HCM
# 18  Tầng 5, Tòa nhà Silver Sea Tower - 47 Ba Cu, P...
# 19  KHU ĐÔ THỊ VCN PHƯỚC HẢI, NHA TRANG, KHÁNH HÒA
#
#                                           Description
# 0   Mô tả:\n+ Thông số cực đẹp 5 x 30m (150m2)\...
# 1   Bán nhà HXH Âu Cơ Phường 9 Tân Bình, 51m2 3 Tầ...
# 2   - Kết cấu: 1 trệt 1 lầu BTCT; 2 PN, 2 WC. Phòn...
# 3   Mô tả:\n- Diện tích công nhận 41m, thực tế 66m...
# 4   - Diện tích 96m2 ngang 4.3m dài 22.5m .\n- sổ ...
# 5   - Vị trí khu vực trung tâm phường La Khê- Hà Đ...
# 6   - Vị trí khu vực trung tâm phường La Khê- Hà Đ...
# 7   + Chủ nhà cần bán gấp nhà phố Hoàng Văn Thái -...
# 8   ✅ BÁN NHÀ MỚI ĐẸP 7 X 13, CHỈ 3.5 TỶ, HẺM XE H...
# 9   SIÊU PHẨM Chào bán căn Biệt Thự mặt đường Lê H...
# 10  Bán Nhà Mặt tiền đường Kha Vạn Cân, P. Linh Đô...
# 11  Bán nhà Âu Cơ-Tây Hồ 42m, NGÕ THÔNG, DÂN XÂY 4...
# 12  CÁCH 1 NHÀ RA MẶT PHỐ ĐÀO TẤN, PHỐ VIP NHẤT BA...
# 13  +-QUẬN 11- MẶT TIỀN 3/2, KINH DOANH SẦM UẤT- K...
# 14  Nhà 6 Tầng, Hộ Khẩu Cầu Giấy, Ô Tô Đỗ Cửa, Ngõ...
# 15  - Hiện có dòng tiền 15 triệu/tháng\n- Kết cấu:...
# 16  + Nhà nằm ngay gần mặt phố Bà Triệu, khu phân ...
# 17  Bán nhà 2 mặt tiền đường Phạm Văn Đồng, Thủ Đứ...
# 18  Cửa nhựa Đài Loan với cấu trúc được sản xuất t...
# 19  ???????????? Với 2 tỉ bạn đã sở hữu shophouse ...
# 0   ???????? Bán nhà mới leng keng 110m2 SHR thổ c...
# 1   ???????? Bán nhà mới leng keng 110m2 SHR thổ c...
# 2   + Vị trí : Mặt tiền ngay trục đường kinh doanh...
# 3   TRUNG TÂM ĐỐNG ĐA - NHÀ GẦN NHIỀU TIỆN ÍCH - T...
# 4   - Vị trí : Trung tâm quận, giao thông đi lại t...
# 5   + Chủ nhà cần bán gấp nhà phố Trường Chinh -tt...
# 6   + Nhà chính chủ, đẹp lung linh. Chỉ cần xách v...
# 7   + Nhà: 1 trệt, 1 lầu\n\n+ Diện tích ngang: 3m ...
# 8   + Bán nhà Văn Quán, Hà Đông, ô tô đỗ cửa, ngõ ...
# 9   - Vị trí : ngay góc 2 mặt tiền đường 12m không...
# 10  11.4 Tỷ Diện Tích 90M2 Nhà 6 Tầng Mặt Tiền Mỹ ...
# 11  - Vị trí xe hơi đỗ cửa ngay PHAN HUY ÍCH, giáp...
# 12  - Bán nhà mặt tiền đường lớn 18m, An Phú, Q2\n...
# 13  T115 Nhà đẹp thoáng, 50m2, ngang 5m, hẻm 1 sẹc...
# 14  ???? Bán nhà Ngõ 267 Hoàng Hoa Thám thẳng tắp?...
# 15  Bán Nhà mặt ngõ Bùi Xương Trạch,, Thanh Xuân, ...
# 16  + DT: gần 40m2 vuông đét\n+ Kết cấu: 4 Tầng đú...
# 17  DT: 4m × 20m × 2m (80m2)\nGiá: 9,39 tỷ (thương...
# 18  The number 1 reputable Google Ads advertising ...
# 19  (PHA12) BÁN NHÀ 2 TẦNG HẺM 3M KHU ĐÔ THỊ VCN ...
