# %% [markdown]
# # Import libraries

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import pandas as pd

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda")

# %% [markdown]
# # Load data

# %%
data = pd.read_csv("../data/train_set_scaled.csv", sep="\t", index_col=0)
data = data.rename(columns={"Log price (1 billion VND)": "Log Price", 'Log area (square meters)': "Log Area", '(Log) Bedrooms' : "Log Bedrooms", '(Log) WC': "Log WC", '(Log) Number of floors': "Log Floors"})

# %%
data.describe()
# Out:
#          Log Price     Log Area  Log Bedrooms       Log WC      Parking  \
# count  4764.000000  4764.000000   4764.000000  4764.000000  4764.000000
# mean     -0.001738    -0.000004      0.000266    -0.000957     0.003535
# std       0.999911     0.995137      0.998461     0.999261     1.000343
# min      -2.492482    -5.430634     -3.161024    -2.674523    -0.933208
# 25%      -0.618843    -0.668842     -0.351505    -1.123405    -0.933208
# 50%      -0.045966    -0.086254      0.384194     0.427712    -0.933208
# 75%       0.574668     0.584781      0.384194     0.427712     1.071573
# max       2.624948     6.825509      6.573883     5.988411     1.071573
#
#           For rent  Infrastructure       Facade   Log Floors     Latitude  \
# count  4764.000000     4764.000000  4764.000000  4764.000000  4764.000000
# mean     -0.013460        0.014805    -0.001661     0.005422     0.005194
# std       0.979637        0.993868     0.999346     0.998988     1.001049
# min      -0.303083       -1.494289    -0.643026    -2.025287    -1.033570
# 25%      -0.303083       -1.494289    -0.643026    -0.698957    -0.685002
# 50%      -0.303083        0.669215    -0.643026     0.076897    -0.674515
# 75%      -0.303083        0.669215     1.555148     0.627374     1.522144
# max       3.299428        0.669215     1.555148     6.898158     1.821403
#
#          Longitude      Cluster  Distance to center 0  Distance to center 1
# count  4764.000000  4764.000000           4764.000000           4764.000000
# mean      0.009009     0.001927              0.005168             -0.005484
# std       1.010348     1.000953              1.001016              1.001752
# min      -4.670233    -0.651906             -0.734891             -1.574407
# 25%      -1.098191    -0.651906             -0.693775             -1.540527
# 50%       0.237872    -0.651906             -0.681493              0.671649
# 75%       0.321129     1.533962              1.521764              0.682305
# max       4.718773     1.533962              1.900324              1.043507

# %%
from sklearn.model_selection import train_test_split

train, valid = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# # Define model

# %% [markdown]
# The architecture is defined as:
# - FFN (Fully connected network): 100 neurons
# - FFN: 100 neurons
# - FFN: 1 neuron
#
# All with ReLU activation function

# %%
model = torch.nn.Sequential()
model.add_module('W0', nn.Linear(data.shape[1] - 1, 100))
model.add_module("relu0", nn.ReLU())
model.add_module('W1', nn.Linear(100, 100))
model.add_module("relu1", nn.ReLU())
model.add_module('W2', nn.Linear(100, 1))

# %% [markdown]
# # Define the Early Stopping

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, model_path='model.pth'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.model_path = model_path

    def __call__(self, val_loss, model, model_path):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.model_path)
        self.val_loss_min = val_loss

# %% [markdown]
# # Define DataLoader

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe:pd.DataFrame, labels:pd.DataFrame) -> None:
        self.data = torch.tensor(dataframe.values, dtype=torch.float32)
        self.labels = torch.tensor(labels.values, dtype=torch.float32)

    def __len__(self) -> int:
        return len(self.data)

    def __getitem__(self, idx) -> tuple:
        return self.data[idx], self.labels[idx]

# %%
train_dataset = CustomDataset(dataframe=train.drop(columns=["Log Price"]), labels=train[["Log Price"]])
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
valid_dataset = CustomDataset(dataframe=valid.drop(columns=["Log Price"]), labels=valid[["Log Price"]])
valid_dataloader = DataLoader(valid_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# # Training loop

# %%
early_stopping = EarlyStopping(patience=10, verbose=True, delta = 0.0001, model_path='model.pth')
num_epochs = 1000
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
model = model.to(device)

for epoch in range(num_epochs):
    running_loss = 0.0
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f'Epoch {epoch+1}, Loss: {running_loss/len(train_dataloader)}')

    for inputs, labels in valid_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs)
        loss = loss_fn(outputs, labels)

        running_loss += loss.item()
    early_stopping(running_loss, model, model_path='model.pth')
    if early_stopping.early_stop:
        print("Early stopping")
        break

print("Done training")
# Out:
# Epoch 1, Loss: 0.6505088277161122
# Validation loss decreased (inf --> 96.346773).  Saving model ...
# Epoch 2, Loss: 0.5913411267101765
# Validation loss decreased (96.346773 --> 88.730482).  Saving model ...
# Epoch 3, Loss: 0.5792119644582272
# Validation loss decreased (88.730482 --> 87.877509).  Saving model ...
# Epoch 4, Loss: 0.5731042571365833
# Validation loss decreased (87.877509 --> 87.008668).  Saving model ...
# Epoch 5, Loss: 0.565469708542029
# Validation loss decreased (87.008668 --> 85.901856).  Saving model ...
# Epoch 6, Loss: 0.5533758183320363
# Validation loss decreased (85.901856 --> 85.003110).  Saving model ...
# Epoch 7, Loss: 0.5458584981039166
# Validation loss decreased (85.003110 --> 83.087383).  Saving model ...
# Epoch 8, Loss: 0.5438173890113831
# Validation loss decreased (83.087383 --> 82.991355).  Saving model ...
# Epoch 9, Loss: 0.5457047405342261
# EarlyStopping counter: 1 out of 10
# Epoch 10, Loss: 0.5329261425882578
# Validation loss decreased (82.991355 --> 81.511733).  Saving model ...
# Epoch 11, Loss: 0.5310848763833443
# Validation loss decreased (81.511733 --> 81.509931).  Saving model ...
# Epoch 12, Loss: 0.5317746937274933
# Validation loss decreased (81.509931 --> 81.505067).  Saving model ...
# Epoch 13, Loss: 0.5226675342768431
# Validation loss decreased (81.505067 --> 80.180578).  Saving model ...
# Epoch 14, Loss: 0.5217401708165804
# EarlyStopping counter: 1 out of 10
# Epoch 15, Loss: 0.5266932368278503
# EarlyStopping counter: 2 out of 10
# Epoch 16, Loss: 0.5217779488613208
# EarlyStopping counter: 3 out of 10
# Epoch 17, Loss: 0.5165346580247084
# Validation loss decreased (80.180578 --> 79.570929).  Saving model ...
# Epoch 18, Loss: 0.5175440539916356
# EarlyStopping counter: 1 out of 10
# Epoch 19, Loss: 0.5103744277109702
# Validation loss decreased (79.570929 --> 79.286285).  Saving model ...
# Epoch 20, Loss: 0.505797562127312
# Validation loss decreased (79.286285 --> 78.396697).  Saving model ...
# Epoch 21, Loss: 0.5066460153708855
# EarlyStopping counter: 1 out of 10
# Epoch 22, Loss: 0.49548694441715874
# Validation loss decreased (78.396697 --> 78.232251).  Saving model ...
# Epoch 23, Loss: 0.5002412224809328
# Validation loss decreased (78.232251 --> 78.148550).  Saving model ...
# Epoch 24, Loss: 0.4946934361476451
# Validation loss decreased (78.148550 --> 77.695360).  Saving model ...
# Epoch 25, Loss: 0.4952561091631651
# Validation loss decreased (77.695360 --> 77.222660).  Saving model ...
# Epoch 26, Loss: 0.5003044992685318
# EarlyStopping counter: 1 out of 10
# Epoch 27, Loss: 0.49715948353211087
# EarlyStopping counter: 2 out of 10
# Epoch 28, Loss: 0.4911888559659322
# Validation loss decreased (77.222660 --> 77.029610).  Saving model ...
# Epoch 29, Loss: 0.4871763230611881
# Validation loss decreased (77.029610 --> 76.636727).  Saving model ...
# Epoch 30, Loss: 0.48685266530762117
# EarlyStopping counter: 1 out of 10
# Epoch 31, Loss: 0.4937356902907292
# EarlyStopping counter: 2 out of 10
# Epoch 32, Loss: 0.4907240721086661
# EarlyStopping counter: 3 out of 10
# Epoch 33, Loss: 0.4832641649991274
# EarlyStopping counter: 4 out of 10
# Epoch 34, Loss: 0.48103044716020427
# Validation loss decreased (76.636727 --> 75.904178).  Saving model ...
# Epoch 35, Loss: 0.4771688892195622
# Validation loss decreased (75.904178 --> 75.800639).  Saving model ...
# Epoch 36, Loss: 0.47693827922145526
# EarlyStopping counter: 1 out of 10
# Epoch 37, Loss: 0.4757292828212182
# EarlyStopping counter: 2 out of 10
# Epoch 38, Loss: 0.47473607075711094
# Validation loss decreased (75.800639 --> 75.259727).  Saving model ...
# Epoch 39, Loss: 0.47287556796024244
# Validation loss decreased (75.259727 --> 75.168344).  Saving model ...
# Epoch 40, Loss: 0.4712870389223099
# EarlyStopping counter: 1 out of 10
# Epoch 41, Loss: 0.46464564502239225
# Validation loss decreased (75.168344 --> 73.672472).  Saving model ...
# Epoch 42, Loss: 0.4657491824279229
# EarlyStopping counter: 1 out of 10
# Epoch 43, Loss: 0.4666318686058124
# EarlyStopping counter: 2 out of 10
# Epoch 44, Loss: 0.46846785085896653
# EarlyStopping counter: 3 out of 10
# Epoch 45, Loss: 0.4610691344986359
# Validation loss decreased (73.672472 --> 73.462638).  Saving model ...
# Epoch 46, Loss: 0.46871355175971985
# EarlyStopping counter: 1 out of 10
# Epoch 47, Loss: 0.464739786212643
# EarlyStopping counter: 2 out of 10
# Epoch 48, Loss: 0.4666019264608622
# EarlyStopping counter: 3 out of 10
# Epoch 49, Loss: 0.45284181348979474
# Validation loss decreased (73.462638 --> 72.449843).  Saving model ...
# Epoch 50, Loss: 0.4575146739681562
# EarlyStopping counter: 1 out of 10
# Epoch 51, Loss: 0.45687829131881397
# EarlyStopping counter: 2 out of 10
# Epoch 52, Loss: 0.4560451867679755
# EarlyStopping counter: 3 out of 10
# Epoch 53, Loss: 0.45191474867363773
# EarlyStopping counter: 4 out of 10
# Epoch 54, Loss: 0.4477848077813784
# Validation loss decreased (72.449843 --> 72.223678).  Saving model ...
# Epoch 55, Loss: 0.4528629084428151
# EarlyStopping counter: 1 out of 10
# Epoch 56, Loss: 0.4477642724911372
# EarlyStopping counter: 2 out of 10
# Epoch 57, Loss: 0.4541076491276423
# EarlyStopping counter: 3 out of 10
# Epoch 58, Loss: 0.4478255451035996
# Validation loss decreased (72.223678 --> 71.985270).  Saving model ...
# Epoch 59, Loss: 0.44796101488173007
# EarlyStopping counter: 1 out of 10
# Epoch 60, Loss: 0.4382680732135971
# Validation loss decreased (71.985270 --> 71.533764).  Saving model ...
# Epoch 61, Loss: 0.44553496725857256
# EarlyStopping counter: 1 out of 10
# Epoch 62, Loss: 0.4500581886619329
# EarlyStopping counter: 2 out of 10
# Epoch 63, Loss: 0.44265770924588044
# EarlyStopping counter: 3 out of 10
# Epoch 64, Loss: 0.43408352248370646
# Validation loss decreased (71.533764 --> 71.099573).  Saving model ...
# Epoch 65, Loss: 0.4332359188546737
# Validation loss decreased (71.099573 --> 70.548982).  Saving model ...
# Epoch 66, Loss: 0.4378156560162703
# EarlyStopping counter: 1 out of 10
# Epoch 67, Loss: 0.4359971462438504
# EarlyStopping counter: 2 out of 10
# Epoch 68, Loss: 0.4277613359193007
# EarlyStopping counter: 3 out of 10
# Epoch 69, Loss: 0.4284981577346722
# Validation loss decreased (70.548982 --> 70.465593).  Saving model ...
# Epoch 70, Loss: 0.4277257642708719
# Validation loss decreased (70.465593 --> 70.292156).  Saving model ...
# Epoch 71, Loss: 0.4304345296074947
# EarlyStopping counter: 1 out of 10
# Epoch 72, Loss: 0.4269780380030473
# EarlyStopping counter: 2 out of 10
# Epoch 73, Loss: 0.4309213622162739
# EarlyStopping counter: 3 out of 10
# Epoch 74, Loss: 0.4274753540754318
# EarlyStopping counter: 4 out of 10
# Epoch 75, Loss: 0.4203308864496648
# EarlyStopping counter: 5 out of 10
# Epoch 76, Loss: 0.4284100078046322
# EarlyStopping counter: 6 out of 10
# Epoch 77, Loss: 0.4192976150661707
# Validation loss decreased (70.292156 --> 69.446393).  Saving model ...
# Epoch 78, Loss: 0.41880436763167384
# EarlyStopping counter: 1 out of 10
# Epoch 79, Loss: 0.4207912656168143
# EarlyStopping counter: 2 out of 10
# Epoch 80, Loss: 0.4184481076275309
# Validation loss decreased (69.446393 --> 68.750927).  Saving model ...
# Epoch 81, Loss: 0.4180322954431176
# EarlyStopping counter: 1 out of 10
# Epoch 82, Loss: 0.4153247207403183
# EarlyStopping counter: 2 out of 10
# Epoch 83, Loss: 0.4238479639093081
# EarlyStopping counter: 3 out of 10
# Epoch 84, Loss: 0.4118860747665167
# EarlyStopping counter: 4 out of 10
# Epoch 85, Loss: 0.4257210767517487
# EarlyStopping counter: 5 out of 10
# Epoch 86, Loss: 0.4242296068618695
# EarlyStopping counter: 6 out of 10
# Epoch 87, Loss: 0.4042805179953575
# Validation loss decreased (68.750927 --> 68.027685).  Saving model ...
# Epoch 88, Loss: 0.41010884443918866
# EarlyStopping counter: 1 out of 10
# Epoch 89, Loss: 0.4057506258289019
# EarlyStopping counter: 2 out of 10
# Epoch 90, Loss: 0.40195209085941314
# EarlyStopping counter: 3 out of 10
# Epoch 91, Loss: 0.4129758983850479
# EarlyStopping counter: 4 out of 10
# Epoch 92, Loss: 0.4113611300786336
# EarlyStopping counter: 5 out of 10
# Epoch 93, Loss: 0.408165459955732
# EarlyStopping counter: 6 out of 10
# Epoch 94, Loss: 0.40404969081282616
# EarlyStopping counter: 7 out of 10
# Epoch 95, Loss: 0.3992466326802969
# Validation loss decreased (68.027685 --> 67.214057).  Saving model ...
# Epoch 96, Loss: 0.3951672066934407
# Validation loss decreased (67.214057 --> 66.811015).  Saving model ...
# Epoch 97, Loss: 0.39658633681635064
# EarlyStopping counter: 1 out of 10
# Epoch 98, Loss: 0.3980520763744911
# EarlyStopping counter: 2 out of 10
# Epoch 99, Loss: 0.3959234170615673
# EarlyStopping counter: 3 out of 10
# Epoch 100, Loss: 0.39417126203576724
# EarlyStopping counter: 4 out of 10
# Epoch 101, Loss: 0.3945858413974444
# EarlyStopping counter: 5 out of 10
# Epoch 102, Loss: 0.388735481533998
# EarlyStopping counter: 6 out of 10
# Epoch 103, Loss: 0.3932898368065556
# EarlyStopping counter: 7 out of 10
# Epoch 104, Loss: 0.3896573230624199
# EarlyStopping counter: 8 out of 10
# Epoch 105, Loss: 0.3923840969800949
# EarlyStopping counter: 9 out of 10
# Epoch 106, Loss: 0.3951567880809307
# EarlyStopping counter: 10 out of 10
# Early stopping
# Done training

# %% [markdown]
# # Evaluate the model

# %%
# how to load model from .pth

model.load_state_dict(torch.load('model.pth'))
model.eval()

test_data = pd.read_csv("../data/test_set_scaled.csv", sep="\t", index_col=0)
test_data = test_data.rename(columns={"Log price (1 billion VND)": "Log Price", 'Log area (square meters)': "Log Area", '(Log) Bedrooms' : "Log Bedrooms", '(Log) WC': "Log WC", '(Log) Number of floors': "Log Floors"})

test_dataset = CustomDataset(dataframe=test_data.drop(columns=["Log Price"]), labels=test_data[["Log Price"]])
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

test_loss = 0.0
for inputs, labels in test_dataloader:
    inputs, labels = inputs.to(device), labels.to(device)

    outputs = model(inputs)
    loss = loss_fn(outputs, labels)

    test_loss += loss.item()

print(f'Test loss: {test_loss/len(test_dataloader)}')
# Out:
# Test loss: 0.433526189135225
