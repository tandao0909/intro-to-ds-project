# %% [markdown]
# # Import libraries

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import pandas as pd

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda")

# %% [markdown]
# # Load data

# %%
data = pd.read_csv("train_set_scaled.csv", sep="\t", index_col=0)
data = data.rename(columns={"Log price (1 billion VND)": "Log Price", 'Log area (square meters)': "Log Area", '(Log) Bedrooms' : "Log Bedrooms", '(Log) WC': "Log WC", '(Log) Number of floors': "Log Floors"})

# %%
data.describe()
# Out:
#          Log Price     Log Area  Log Bedrooms       Log WC      Parking  \
# count  4764.000000  4764.000000   4764.000000  4764.000000  4764.000000
# mean     -0.001738    -0.000004      0.000266    -0.000957     0.003535
# std       0.999911     0.995137      0.998461     0.999261     1.000343
# min      -2.492482    -5.430634     -3.161024    -2.674523    -0.933208
# 25%      -0.618843    -0.668842     -0.351505    -1.123405    -0.933208
# 50%      -0.045966    -0.086254      0.384194     0.427712    -0.933208
# 75%       0.574668     0.584781      0.384194     0.427712     1.071573
# max       2.624948     6.825509      6.573883     5.988411     1.071573
#
#           For rent  Infrastructure       Facade   Log Floors     Latitude  \
# count  4764.000000     4764.000000  4764.000000  4764.000000  4764.000000
# mean     -0.013460        0.014805    -0.001661     0.005422     0.005194
# std       0.979637        0.993868     0.999346     0.998988     1.001049
# min      -0.303083       -1.494289    -0.643026    -2.025287    -1.033570
# 25%      -0.303083       -1.494289    -0.643026    -0.698957    -0.685002
# 50%      -0.303083        0.669215    -0.643026     0.076897    -0.674515
# 75%      -0.303083        0.669215     1.555148     0.627374     1.522144
# max       3.299428        0.669215     1.555148     6.898158     1.821403
#
#          Longitude      Cluster  Distance to center 0  Distance to center 1
# count  4764.000000  4764.000000           4764.000000           4764.000000
# mean      0.009009     0.001927              0.005168             -0.005484
# std       1.010348     1.000953              1.001016              1.001752
# min      -4.670233    -0.651906             -0.734891             -1.574407
# 25%      -1.098191    -0.651906             -0.693775             -1.540527
# 50%       0.237872    -0.651906             -0.681493              0.671649
# 75%       0.321129     1.533962              1.521764              0.682305
# max       4.718773     1.533962              1.900324              1.043507

# %%
from sklearn.model_selection import train_test_split

train, valid = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# # Define model

# %% [markdown]
# The architecture is defined as:
# - FFN (Fully connected network): 100 neurons
# - FFN: 100 neurons
# - FFN: 1 neuron
#
# All with ReLU activation function

# %%
model = torch.nn.Sequential()
model.add_module('W0', nn.Linear(data.shape[1] - 1, 100))
model.add_module("relu0", nn.ReLU())
model.add_module('W1', nn.Linear(100, 100))
model.add_module("relu1", nn.ReLU())
model.add_module('W2', nn.Linear(100, 1))

# %% [markdown]
# # Define the Early Stopping

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, model_path='model.pth'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.model_path = model_path

    def __call__(self, val_loss, model, model_path):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.model_path)
        self.val_loss_min = val_loss

# %% [markdown]
# # Define DataLoader

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe:pd.DataFrame, labels:pd.DataFrame) -> None:
        self.data = torch.tensor(dataframe.values, dtype=torch.float32)
        self.labels = torch.tensor(labels.values, dtype=torch.float32)

    def __len__(self) -> int:
        return len(self.data)

    def __getitem__(self, idx) -> tuple:
        return self.data[idx], self.labels[idx]

# %%
train_dataset = CustomDataset(dataframe=train.drop(columns=["Log Price"]), labels=train[["Log Price"]])
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
valid_dataset = CustomDataset(dataframe=valid.drop(columns=["Log Price"]), labels=valid[["Log Price"]])
valid_dataloader = DataLoader(valid_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# # Training loop

# %%
early_stopping = EarlyStopping(patience=10, verbose=True, delta = 0.0001, model_path='model.pth')
num_epochs = 1000
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
model = model.to(device)

for epoch in range(num_epochs):
    running_loss = 0.0
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f'Epoch {epoch+1}, Loss: {running_loss/len(train_dataloader)}')

    for inputs, labels in valid_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs)
        loss = loss_fn(outputs, labels)

        running_loss += loss.item()
    early_stopping(running_loss, model, model_path='model.pth')
    if early_stopping.early_stop:
        print("Early stopping")
        break

print("Done training")
# Out:
# Epoch 1, Loss: 0.656785455873857
# Validation loss decreased (inf --> 96.386630).  Saving model ...
# Epoch 2, Loss: 0.5693589134762684
# Validation loss decreased (96.386630 --> 85.519365).  Saving model ...
# Epoch 3, Loss: 0.5422917294005553
# Validation loss decreased (85.519365 --> 81.978316).  Saving model ...
# Epoch 4, Loss: 0.5246468211213747
# Validation loss decreased (81.978316 --> 79.363017).  Saving model ...
# Epoch 5, Loss: 0.5228549532592297
# Validation loss decreased (79.363017 --> 78.797631).  Saving model ...
# Epoch 6, Loss: 0.5024291360129912
# Validation loss decreased (78.797631 --> 76.765183).  Saving model ...
# Epoch 7, Loss: 0.4977802916119496
# Validation loss decreased (76.765183 --> 76.210147).  Saving model ...
# Epoch 8, Loss: 0.5053528594473998
# EarlyStopping counter: 1 out of 10
# Epoch 9, Loss: 0.4843359120190144
# Validation loss decreased (76.210147 --> 74.267430).  Saving model ...
# Epoch 10, Loss: 0.4769165017952522
# Validation loss decreased (74.267430 --> 73.396576).  Saving model ...
# Epoch 11, Loss: 0.47454547000428043
# EarlyStopping counter: 1 out of 10
# Epoch 12, Loss: 0.4723034399251143
# Validation loss decreased (73.396576 --> 72.470421).  Saving model ...
# Epoch 13, Loss: 0.46443191965421043
# Validation loss decreased (72.470421 --> 71.468714).  Saving model ...
# Epoch 14, Loss: 0.468732184668382
# EarlyStopping counter: 1 out of 10
# Epoch 15, Loss: 0.4622887286047141
# Validation loss decreased (71.468714 --> 71.202395).  Saving model ...
# Epoch 16, Loss: 0.44974983061353363
# Validation loss decreased (71.202395 --> 70.532616).  Saving model ...
# Epoch 17, Loss: 0.4431241157154242
# Validation loss decreased (70.532616 --> 69.238751).  Saving model ...
# Epoch 18, Loss: 0.44772472338130076
# EarlyStopping counter: 1 out of 10
# Epoch 19, Loss: 0.4483161592235168
# EarlyStopping counter: 2 out of 10
# Epoch 20, Loss: 0.4360661473125219
# Validation loss decreased (69.238751 --> 68.307929).  Saving model ...
# Epoch 21, Loss: 0.4331370004763206
# EarlyStopping counter: 1 out of 10
# Epoch 22, Loss: 0.43240059092640876
# EarlyStopping counter: 2 out of 10
# Epoch 23, Loss: 0.4307233805457751
# Validation loss decreased (68.307929 --> 67.975226).  Saving model ...
# Epoch 24, Loss: 0.42246089937786263
# Validation loss decreased (67.975226 --> 67.621969).  Saving model ...
# Epoch 25, Loss: 0.42604157763222855
# Validation loss decreased (67.621969 --> 67.587653).  Saving model ...
# Epoch 26, Loss: 0.4176768663028876
# Validation loss decreased (67.587653 --> 66.478629).  Saving model ...
# Epoch 27, Loss: 0.4196054623772701
# EarlyStopping counter: 1 out of 10
# Epoch 28, Loss: 0.4212277124946316
# EarlyStopping counter: 2 out of 10
# Epoch 29, Loss: 0.4099887685229381
# Validation loss decreased (66.478629 --> 65.847901).  Saving model ...
# Epoch 30, Loss: 0.4102363078544537
# EarlyStopping counter: 1 out of 10
# Epoch 31, Loss: 0.4045680118724704
# Validation loss decreased (65.847901 --> 64.602032).  Saving model ...
# Epoch 32, Loss: 0.39792272945245105
# EarlyStopping counter: 1 out of 10
# Epoch 33, Loss: 0.396156053741773
# Validation loss decreased (64.602032 --> 63.977633).  Saving model ...
# Epoch 34, Loss: 0.3955675005912781
# EarlyStopping counter: 1 out of 10
# Epoch 35, Loss: 0.3943065097555518
# EarlyStopping counter: 2 out of 10
# Epoch 36, Loss: 0.3858238872140646
# Validation loss decreased (63.977633 --> 63.927993).  Saving model ...
# Epoch 37, Loss: 0.3867059472327431
# Validation loss decreased (63.927993 --> 63.550281).  Saving model ...
# Epoch 38, Loss: 0.38824604271600643
# EarlyStopping counter: 1 out of 10
# Epoch 39, Loss: 0.39029902356366314
# EarlyStopping counter: 2 out of 10
# Epoch 40, Loss: 0.37789141163229945
# Validation loss decreased (63.550281 --> 62.602919).  Saving model ...
# Epoch 41, Loss: 0.37472553302844364
# Validation loss decreased (62.602919 --> 62.251480).  Saving model ...
# Epoch 42, Loss: 0.3721666898578405
# Validation loss decreased (62.251480 --> 61.695436).  Saving model ...
# Epoch 43, Loss: 0.3697732351720333
# Validation loss decreased (61.695436 --> 61.545458).  Saving model ...
# Epoch 44, Loss: 0.36683042521278064
# Validation loss decreased (61.545458 --> 60.626043).  Saving model ...
# Epoch 45, Loss: 0.37270465555290383
# EarlyStopping counter: 1 out of 10
# Epoch 46, Loss: 0.3688619581361612
# EarlyStopping counter: 2 out of 10
# Epoch 47, Loss: 0.358276071647803
# Validation loss decreased (60.626043 --> 60.410599).  Saving model ...
# Epoch 48, Loss: 0.3653561102847258
# EarlyStopping counter: 1 out of 10
# Epoch 49, Loss: 0.35871164202690126
# Validation loss decreased (60.410599 --> 60.212865).  Saving model ...
# Epoch 50, Loss: 0.3539163339883089
# Validation loss decreased (60.212865 --> 59.751246).  Saving model ...
# Epoch 51, Loss: 0.354307979469498
# Validation loss decreased (59.751246 --> 59.508768).  Saving model ...
# Epoch 52, Loss: 0.3450362001856168
# Validation loss decreased (59.508768 --> 59.025989).  Saving model ...
# Epoch 53, Loss: 0.34874133256574474
# EarlyStopping counter: 1 out of 10
# Epoch 54, Loss: 0.34750120937824247
# EarlyStopping counter: 2 out of 10
# Epoch 55, Loss: 0.34603897829850516
# Validation loss decreased (59.025989 --> 58.393909).  Saving model ...
# Epoch 56, Loss: 0.3460593911508719
# EarlyStopping counter: 1 out of 10
# Epoch 57, Loss: 0.35208600101371607
# EarlyStopping counter: 2 out of 10
# Epoch 58, Loss: 0.34284439105540515
# EarlyStopping counter: 3 out of 10
# Epoch 59, Loss: 0.3383422202120225
# EarlyStopping counter: 4 out of 10
# Epoch 60, Loss: 0.3372362627958258
# Validation loss decreased (58.393909 --> 58.318371).  Saving model ...
# Epoch 61, Loss: 0.3257139296581348
# Validation loss decreased (58.318371 --> 56.476584).  Saving model ...
# Epoch 62, Loss: 0.3307129205359767
# EarlyStopping counter: 1 out of 10
# Epoch 63, Loss: 0.32750422234336535
# EarlyStopping counter: 2 out of 10
# Epoch 64, Loss: 0.327351401373744
# EarlyStopping counter: 3 out of 10
# Epoch 65, Loss: 0.32599810920655725
# EarlyStopping counter: 4 out of 10
# Epoch 66, Loss: 0.32083387648065886
# EarlyStopping counter: 5 out of 10
# Epoch 67, Loss: 0.33010669412712257
# EarlyStopping counter: 6 out of 10
# Epoch 68, Loss: 0.32795199727018676
# EarlyStopping counter: 7 out of 10
# Epoch 69, Loss: 0.31832558910051983
# Validation loss decreased (56.476584 --> 56.151500).  Saving model ...
# Epoch 70, Loss: 0.3194587140654524
# Validation loss decreased (56.151500 --> 55.968444).  Saving model ...
# Epoch 71, Loss: 0.31232229160765806
# Validation loss decreased (55.968444 --> 55.922872).  Saving model ...
# Epoch 72, Loss: 0.31157618078092736
# Validation loss decreased (55.922872 --> 55.440094).  Saving model ...
# Epoch 73, Loss: 0.3134334124624729
# Validation loss decreased (55.440094 --> 55.331647).  Saving model ...
# Epoch 74, Loss: 0.3060912350192666
# Validation loss decreased (55.331647 --> 54.505232).  Saving model ...
# Epoch 75, Loss: 0.30427315570414065
# EarlyStopping counter: 1 out of 10
# Epoch 76, Loss: 0.317587556814154
# EarlyStopping counter: 2 out of 10
# Epoch 77, Loss: 0.31162453076491753
# EarlyStopping counter: 3 out of 10
# Epoch 78, Loss: 0.30100702854494255
# Validation loss decreased (54.505232 --> 54.366320).  Saving model ...
# Epoch 79, Loss: 0.3058952900891503
# EarlyStopping counter: 1 out of 10
# Epoch 80, Loss: 0.32157903822759787
# EarlyStopping counter: 2 out of 10
# Epoch 81, Loss: 0.2966222785723706
# Validation loss decreased (54.366320 --> 53.588752).  Saving model ...
# Epoch 82, Loss: 0.28746026984105505
# Validation loss decreased (53.588752 --> 52.881596).  Saving model ...
# Epoch 83, Loss: 0.29103721665839355
# EarlyStopping counter: 1 out of 10
# Epoch 84, Loss: 0.3037677887827158
# EarlyStopping counter: 2 out of 10
# Epoch 85, Loss: 0.29119597499569255
# EarlyStopping counter: 3 out of 10
# Epoch 86, Loss: 0.2866817263265451
# EarlyStopping counter: 4 out of 10
# Epoch 87, Loss: 0.29132312946021555
# EarlyStopping counter: 5 out of 10
# Epoch 88, Loss: 0.2848242481549581
# Validation loss decreased (52.881596 --> 52.146714).  Saving model ...
# Epoch 89, Loss: 0.28461770694702865
# EarlyStopping counter: 1 out of 10
# Epoch 90, Loss: 0.2821283914148808
# EarlyStopping counter: 2 out of 10
# Epoch 91, Loss: 0.27922893899182477
# EarlyStopping counter: 3 out of 10
# Epoch 92, Loss: 0.28711104169487955
# EarlyStopping counter: 4 out of 10
# Epoch 93, Loss: 0.28373576619972785
# EarlyStopping counter: 5 out of 10
# Epoch 94, Loss: 0.27466133365329976
# Validation loss decreased (52.146714 --> 51.166997).  Saving model ...
# Epoch 95, Loss: 0.27260109086831413
# EarlyStopping counter: 1 out of 10
# Epoch 96, Loss: 0.2814050731559595
# EarlyStopping counter: 2 out of 10
# Epoch 97, Loss: 0.27362420394395787
# EarlyStopping counter: 3 out of 10
# Epoch 98, Loss: 0.2658585090190172
# Validation loss decreased (51.166997 --> 50.401872).  Saving model ...
# Epoch 99, Loss: 0.27544755171984436
# EarlyStopping counter: 1 out of 10
# Epoch 100, Loss: 0.2684714584300915
# EarlyStopping counter: 2 out of 10
# Epoch 101, Loss: 0.2686733014881611
# EarlyStopping counter: 3 out of 10
# Epoch 102, Loss: 0.2714313310260574
# EarlyStopping counter: 4 out of 10
# Epoch 103, Loss: 0.26613979805260896
# EarlyStopping counter: 5 out of 10
# Epoch 104, Loss: 0.2638467610503236
# EarlyStopping counter: 6 out of 10
# Epoch 105, Loss: 0.26402931498984494
# EarlyStopping counter: 7 out of 10
# Epoch 106, Loss: 0.26426870891203486
# EarlyStopping counter: 8 out of 10
# Epoch 107, Loss: 0.2599620849515001
# Validation loss decreased (50.401872 --> 49.960741).  Saving model ...
# Epoch 108, Loss: 0.2586943279951811
# EarlyStopping counter: 1 out of 10
# Epoch 109, Loss: 0.2597549012551705
# Validation loss decreased (49.960741 --> 49.933697).  Saving model ...
# Epoch 110, Loss: 0.25756604578346015
# Validation loss decreased (49.933697 --> 49.803548).  Saving model ...
# Epoch 111, Loss: 0.25685574573775133
# Validation loss decreased (49.803548 --> 49.530652).  Saving model ...
# Epoch 112, Loss: 0.26138113855073847
# EarlyStopping counter: 1 out of 10
# Epoch 113, Loss: 0.25329221367525556
# EarlyStopping counter: 2 out of 10
# Epoch 114, Loss: 0.2570963276550174
# EarlyStopping counter: 3 out of 10
# Epoch 115, Loss: 0.24855529045065244
# Validation loss decreased (49.530652 --> 49.316530).  Saving model ...
# Epoch 116, Loss: 0.248089803258578
# EarlyStopping counter: 1 out of 10
# Epoch 117, Loss: 0.26062560894836984
# EarlyStopping counter: 2 out of 10
# Epoch 118, Loss: 0.26510828183963897
# EarlyStopping counter: 3 out of 10
# Epoch 119, Loss: 0.2552401706576347
# EarlyStopping counter: 4 out of 10
# Epoch 120, Loss: 0.25779331574837366
# EarlyStopping counter: 5 out of 10
# Epoch 121, Loss: 0.2458572105815013
# EarlyStopping counter: 6 out of 10
# Epoch 122, Loss: 0.2505712614705165
# EarlyStopping counter: 7 out of 10
# Epoch 123, Loss: 0.24364711580177148
# Validation loss decreased (49.316530 --> 48.207774).  Saving model ...
# Epoch 124, Loss: 0.24048912028471628
# Validation loss decreased (48.207774 --> 47.940296).  Saving model ...
# Epoch 125, Loss: 0.24963926151394844
# EarlyStopping counter: 1 out of 10
# Epoch 126, Loss: 0.2499090005022784
# EarlyStopping counter: 2 out of 10
# Epoch 127, Loss: 0.24307311500112216
# EarlyStopping counter: 3 out of 10
# Epoch 128, Loss: 0.2431757801522811
# EarlyStopping counter: 4 out of 10
# Epoch 129, Loss: 0.2363002915556232
# Validation loss decreased (47.940296 --> 47.931823).  Saving model ...
# Epoch 130, Loss: 0.24295147409041723
# EarlyStopping counter: 1 out of 10
# Epoch 131, Loss: 0.26204420092205205
# EarlyStopping counter: 2 out of 10
# Epoch 132, Loss: 0.23637392414578548
# EarlyStopping counter: 3 out of 10
# Epoch 133, Loss: 0.23033142325778802
# Validation loss decreased (47.931823 --> 47.659722).  Saving model ...
# Epoch 134, Loss: 0.2383214605351289
# EarlyStopping counter: 1 out of 10
# Epoch 135, Loss: 0.24063003339494268
# EarlyStopping counter: 2 out of 10
# Epoch 136, Loss: 0.23753583785146476
# EarlyStopping counter: 3 out of 10
# Epoch 137, Loss: 0.23839582428336142
# EarlyStopping counter: 4 out of 10
# Epoch 138, Loss: 0.23665038260320823
# EarlyStopping counter: 5 out of 10
# Epoch 139, Loss: 0.229609529611965
# Validation loss decreased (47.659722 --> 47.069221).  Saving model ...
# Epoch 140, Loss: 0.22882161879291138
# EarlyStopping counter: 1 out of 10
# Epoch 141, Loss: 0.23044678717851638
# EarlyStopping counter: 2 out of 10
# Epoch 142, Loss: 0.22869697104518613
# EarlyStopping counter: 3 out of 10
# Epoch 143, Loss: 0.22773571633733808
# EarlyStopping counter: 4 out of 10
# Epoch 144, Loss: 0.23338433944930634
# EarlyStopping counter: 5 out of 10
# Epoch 145, Loss: 0.240003025966386
# EarlyStopping counter: 6 out of 10
# Epoch 146, Loss: 0.22801135573536158
# EarlyStopping counter: 7 out of 10
# Epoch 147, Loss: 0.22662923658887546
# EarlyStopping counter: 8 out of 10
# Epoch 148, Loss: 0.22423635320737959
# EarlyStopping counter: 9 out of 10
# Epoch 149, Loss: 0.22193549890071154
# Validation loss decreased (47.069221 --> 46.191317).  Saving model ...
# Epoch 150, Loss: 0.22366004915287097
# EarlyStopping counter: 1 out of 10
# Epoch 151, Loss: 0.22739733414103588
# EarlyStopping counter: 2 out of 10
# Epoch 152, Loss: 0.2263516632335571
# EarlyStopping counter: 3 out of 10
# Epoch 153, Loss: 0.22107887311528127
# EarlyStopping counter: 4 out of 10
# Epoch 154, Loss: 0.22023531080534062
# EarlyStopping counter: 5 out of 10
# Epoch 155, Loss: 0.2180564785686632
# EarlyStopping counter: 6 out of 10
# Epoch 156, Loss: 0.22142578947047392
# EarlyStopping counter: 7 out of 10
# Epoch 157, Loss: 0.21546288368602592
# EarlyStopping counter: 8 out of 10
# Epoch 158, Loss: 0.21624158391108114
# EarlyStopping counter: 9 out of 10
# Epoch 159, Loss: 0.21723168169458706
# EarlyStopping counter: 10 out of 10
# Early stopping
# Done training

# %% [markdown]
# # Evaluate the model

# %%
# how to load model from .pth

model.load_state_dict(torch.load('model.pth'))
model.eval()

test_data = pd.read_csv("test_set_scaled.csv", sep="\t", index_col=0)
test_data = test_data.rename(columns={"Log price (1 billion VND)": "Log Price", 'Log area (square meters)': "Log Area", '(Log) Bedrooms' : "Log Bedrooms", '(Log) WC': "Log WC", '(Log) Number of floors': "Log Floors"})

test_dataset = CustomDataset(dataframe=test_data.drop(columns=["Log Price"]), labels=test_data[["Log Price"]])
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

test_loss = 0.0
for inputs, labels in test_dataloader:
    inputs, labels = inputs.to(device), labels.to(device)

    outputs = model(inputs)
    loss = loss_fn(outputs, labels)

    test_loss += loss.item()

print(f'Test loss: {test_loss/len(test_dataloader)}')
# Out:
# Test loss: 0.6571103059931805
